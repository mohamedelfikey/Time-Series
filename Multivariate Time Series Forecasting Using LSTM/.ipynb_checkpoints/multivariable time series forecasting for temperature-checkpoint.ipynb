# %% [markdown]
# # Part one import libraries and read data

# %%
import os
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('always')

# %%
df=pd.read_csv("Weather Data.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# 1               8.0     101.24                   Fog
# 2               4.0     101.26  Freezing Drizzle,Fog
# 3               4.0     101.27  Freezing Drizzle,Fog
# 4               4.8     101.23                   Fog
# ...             ...        ...                   ...
# 8779            9.7     100.13                  Snow
# 8780            9.7     100.03                  Snow
# 8781            4.8      99.95                  Snow
# 8782            9.7      99.91                  Snow
# 8783           11.3      99.89                  Snow
#
# [8784 rows x 8 columns]

# %% [markdown]
# ### describe data

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.drop("Weather" , axis=1,inplace=True)

# %%
df["Date/Time"]=pd.to_datetime(df["Date/Time"])

# %%
print (f"The maximum datetime: {df['Date/Time'].max()}")
print (f"The minmum datetime: {df['Date/Time'].min()}")
# Out:
# The maximum datetime: 2012-12-31 23:00:00
# The minmum datetime: 2012-01-01 00:00:00

# %%
df.rename({"Date/Time" : "Date"} ,axis=1,inplace=True)
df.index=df["Date"]
df.drop("Date",axis=1,inplace=True)
df
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
# 2012-12-31 23:00:00     0.0              -2.1         86               30
#
#                      Visibility_km  Press_kPa
# Date
# 2012-01-01 00:00:00            8.0     101.24
# 2012-01-01 01:00:00            8.0     101.24
# 2012-01-01 02:00:00            4.0     101.26
# 2012-01-01 03:00:00            4.0     101.27
# 2012-01-01 04:00:00            4.8     101.23
# ...                            ...        ...
# 2012-12-31 19:00:00            9.7     100.13
# 2012-12-31 20:00:00            9.7     100.03
# 2012-12-31 21:00:00            4.8      99.95
# 2012-12-31 22:00:00            9.7      99.91
# 2012-12-31 23:00:00           11.3      99.89
#
# [8784 rows x 6 columns]

# %% [markdown]
# # Part Four Train Test split

# %%
# [[[t1,d1,r1,w1,v1,p1],[t2,d2,r2,w2,v2,p2],[t3,d3,r3,w3,v3,p3],[t4,d4,r4,w4,v4,p4],[t5,d5,r5,w5,v5,p5]]],[t6,d6,r6,w6,v6,p6]
# [[[t2,d2,r2,w2,v2,p2],[t3,d3,r3,w3,v3,p3],[t4,d4,r4,w4,v4,p4],[t5,d5,r5,w5,v5,p5],[t6,d6,r6,w6,v6,p6]]],[t7,d7,r7,w7,v7,p7]
# [[[t3,d3,r3,w3,v3,p3],[t4,d4,r4,w4,v4,p4],[t5,d5,r5,w5,v5,p5],[t6,d6,r6,w6,v6,p6],[t7,d7,r7,w7,v7,p7]]],[t8,d8,r8,w8,v8,p8]

def df_to_x_y(df,window_size=5):
    df_as_np=df.to_numpy()
    x=[]
    y=[]
    for i in range(len(df_as_np)-window_size):
        row=df_as_np[i:i+window_size]
        x.append(row)
        label=df_as_np[i+window_size][0]
        y.append(label)
    return np.array(x) ,np.array(y)

# %%
x,y=df_to_x_y(df)
print (x.shape,y.shape)
# Out:
# (8779, 5, 6) (8779,)

# %%
x_train=x[:6500]
y_train=y[:6500]
x_val=x[6500:7500]
y_val=y[6500:7500]
x_test=x[7500:]
y_test=y[7500:]


print (f'x_train.shape:{x_train.shape} , y_train.shape: {y_train.shape}')
print (f'x_val.shape:{x_val.shape} , y_val.shape: {y_val.shape}')
print (f'x_test.shape:{x_test.shape} , y_test.shape: {y_test.shape}')
# Out:
# x_train.shape:(6500, 5, 6) , y_train.shape: (6500,)
# x_val.shape:(1000, 5, 6) , y_val.shape: (1000,)
# x_test.shape:(1279, 5, 6) , y_test.shape: (1279,)

# %% [markdown]
# ### standrization input data

# %%
temp_training_mean=np.mean(x_train[:,:])
temp_training_std=np.std(x_train[:,:])

def standrization (x):
    x[:,:]=(x[:,:] - temp_training_mean)/temp_training_std
    return x

# %%
standrization(x_train)
standrization(x_val)
standrization(x_test)
# Out:
# array([[[-0.91468179, -1.12012759,  0.56726729, -0.36408703,
#          -0.36134775,  1.75310048],
#         [-0.89276757, -1.11190976,  0.51248174, -0.30930148,
#          -0.36134775,  1.75173085],
#         [-0.88181046, -1.11464904,  0.4576962 , -0.30930148,
#          -0.36134775,  1.75090906],
#         [-0.87907118, -1.11190976,  0.4576962 , -0.47365812,
#          -0.36134775,  1.75008728],
#         [-0.9009854 , -1.12560615,  0.48508897, -0.5010509 ,
#          -0.36134775,  1.74981335]],
#
#        [[-0.89276757, -1.11190976,  0.51248174, -0.30930148,
#          -0.36134775,  1.75173085],
#         [-0.88181046, -1.11464904,  0.4576962 , -0.30930148,
#          -0.36134775,  1.75090906],
#         [-0.87907118, -1.11190976,  0.4576962 , -0.47365812,
#          -0.36134775,  1.75008728],
#         [-0.9009854 , -1.12560615,  0.48508897, -0.5010509 ,
#          -0.36134775,  1.74981335],
#         [-0.93385673, -1.13656326,  0.56726729, -0.66540754,
#          -0.36134775,  1.75063514]],
#
#        [[-0.88181046, -1.11464904,  0.4576962 , -0.30930148,
#          -0.36134775,  1.75090906],
#         [-0.87907118, -1.11190976,  0.4576962 , -0.47365812,
#          -0.36134775,  1.75008728],
#         [-0.9009854 , -1.12560615,  0.48508897, -0.5010509 ,
#          -0.36134775,  1.74981335],
#         [-0.93385673, -1.13656326,  0.56726729, -0.66540754,
#          -0.36134775,  1.75063514],
#         [-0.95577095, -1.10369193,  0.81380226, -0.82976419,
#          -0.33669425,  1.75200477]],
#
#        ...,
#
#        [[-1.05986349, -1.1310847 ,  1.22469387, -0.66540754,
#          -0.66814682,  1.72872092],
#         [-1.05164566, -1.11190976,  1.30687219, -0.5010509 ,
#          -0.7558037 ,  1.72598164],
#         [-1.05712421, -1.10643121,  1.38905052, -0.55583645,
#          -0.7558037 ,  1.72296843],
#         [-1.01877433, -1.0954741 ,  1.1973011 , -0.19973038,
#          -0.7558037 ,  1.72132487],
#         [-1.01603505, -1.08725626,  1.25208665, -0.36408703,
#          -0.7558037 ,  1.71858559]],
#
#        [[-1.05164566, -1.11190976,  1.30687219, -0.5010509 ,
#          -0.7558037 ,  1.72598164],
#         [-1.05712421, -1.10643121,  1.38905052, -0.55583645,
#          -0.7558037 ,  1.72296843],
#         [-1.01877433, -1.0954741 ,  1.1973011 , -0.19973038,
#          -0.7558037 ,  1.72132487],
#         [-1.01603505, -1.08725626,  1.25208665, -0.36408703,
#          -0.7558037 ,  1.71858559],
#         [-1.03520999, -1.06260277,  1.52601439, -0.25451593,
#          -0.89002829,  1.71639417]],
#
#        [[-1.05712421, -1.10643121,  1.38905052, -0.55583645,
#          -0.7558037 ,  1.72296843],
#         [-1.01877433, -1.0954741 ,  1.1973011 , -0.19973038,
#          -0.7558037 ,  1.72132487],
#         [-1.01603505, -1.08725626,  1.25208665, -0.36408703,
#          -0.7558037 ,  1.71858559],
#         [-1.03520999, -1.06260277,  1.52601439, -0.25451593,
#          -0.89002829,  1.71639417],
#         [-1.02699216, -1.0708206 ,  1.41644329, -0.25451593,
#          -0.7558037 ,  1.71529846]]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam


model=Sequential()
model.add(InputLayer((5,6)))
model.add(LSTM(units=128,return_sequences=True))
model.add(LSTM(units=128,return_sequences=True))
# model.add(LSTM(units=128,return_sequences=True))
model.add(LSTM(units=128,return_sequences=False))

model.add(Dense(64,'relu'))
model.add(Dense(1,'linear'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 5, 128)              │          69,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 209,025 (816.50 KB)
#  Trainable params: 209,025 (816.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model/model.keras', save_best_only=True)
model.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.0001),metrics=[RootMeanSquaredError()])

# %%
model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs=20,callbacks=cp)
# Out:
# Epoch 1/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8655 - root_mean_squared_error: 0.9301 - val_loss: 0.6835 - val_root_mean_squared_error: 0.8214
# Epoch 2/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8738 - root_mean_squared_error: 0.9347 - val_loss: 0.6156 - val_root_mean_squared_error: 0.7833
# Epoch 3/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8285 - root_mean_squared_error: 0.9099 - val_loss: 0.6252 - val_root_mean_squared_error: 0.7934
# Epoch 4/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8986 - root_mean_squared_error: 0.9466 - val_loss: 0.6542 - val_root_mean_squared_error: 0.8059
# Epoch 5/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8899 - root_mean_squared_error: 0.9430 - val_loss: 1.4396 - val_root_mean_squared_error: 1.2088
# Epoch 6/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.9438 - root_mean_squared_error: 0.9707 - val_loss: 0.6415 - val_root_mean_squared_error: 0.8030
# Epoch 7/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8494 - root_mean_squared_error: 0.9208 - val_loss: 0.8510 - val_root_mean_squared_error: 0.9279
# Epoch 8/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.8936 - root_mean_squared_error: 0.9451 - val_loss: 0.6272 - val_root_mean_squared_error: 0.7948
# Epoch 9/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8040 - root_mean_squared_error: 0.8961 - val_loss: 0.7496 - val_root_mean_squared_error: 0.8694
# Epoch 10/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7958 - root_mean_squared_error: 0.8916 - val_loss: 0.7370 - val_root_mean_squared_error: 0.8630
# Epoch 11/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8044 - root_mean_squared_error: 0.8966 - val_loss: 0.7728 - val_root_mean_squared_error: 0.8772
# Epoch 12/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8957 - root_mean_squared_error: 0.9461 - val_loss: 0.6878 - val_root_mean_squared_error: 0.8249
# Epoch 13/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8703 - root_mean_squared_error: 0.9326 - val_loss: 0.6491 - val_root_mean_squared_error: 0.8032
# Epoch 14/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8326 - root_mean_squared_error: 0.9121 - val_loss: 0.8535 - val_root_mean_squared_error: 0.9283
# Epoch 15/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.7913 - root_mean_squared_error: 0.8891 - val_loss: 0.6165 - val_root_mean_squared_error: 0.7859
# Epoch 16/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7859 - root_mean_squared_error: 0.8860 - val_loss: 0.7330 - val_root_mean_squared_error: 0.8601
# Epoch 17/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.9411 - root_mean_squared_error: 0.9684 - val_loss: 0.6148 - val_root_mean_squared_error: 0.7869
# Epoch 18/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8200 - root_mean_squared_error: 0.9054 - val_loss: 0.6677 - val_root_mean_squared_error: 0.8210
# Epoch 19/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.9169 - root_mean_squared_error: 0.9568 - val_loss: 0.7658 - val_root_mean_squared_error: 0.8702
# Epoch 20/20
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.9182 - root_mean_squared_error: 0.9573 - val_loss: 0.7036 - val_root_mean_squared_error: 0.8425

# %% [markdown]
# ### make predications

# %%
from tensorflow.keras.models import load_model
model=load_model('model/model.keras')

# %%
train_pred=model.predict(x_train).flatten()
train_result=pd.DataFrame(data={"actual":y_train,"pred":train_pred})
train_result
# Out:
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
#       actual       pred
# 0       -1.4  -1.498593
# 1       -1.5  -1.412637
# 2       -1.4  -1.354579
# 3       -1.4  -1.437406
# 4       -1.3  -1.485500
# ...      ...        ...
# 6495    11.5   9.553910
# 6496     9.4  10.943042
# 6497     9.3   8.792958
# 6498     9.2   9.063928
# 6499     9.2   9.069243
#
# [6500 rows x 2 columns]

# %%
fig=plt.figure(figsize=(25,8))
plt.plot(y_train)
plt.plot(train_pred)
plt.legend(['actual','predication'])
plt.title("Actual train VS Pred train")
plt.show()

# %%
val_pred=model.predict(x_val).flatten()
val_result=pd.DataFrame(data={"actual":y_val,"pred":val_pred})
val_result
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#      actual      pred
# 0       8.0  8.988179
# 1       8.9  7.931699
# 2       7.2  9.147529
# 3       6.0  7.184911
# 4       5.1  6.132966
# ..      ...       ...
# 995     3.9  2.736995
# 996     4.7  4.126328
# 997     5.1  4.928228
# 998     5.2  5.178811
# 999     4.4  5.218596
#
# [1000 rows x 2 columns]

# %%
fig=plt.figure(figsize=(15,8))
plt.plot(y_val)
plt.plot(val_pred)
plt.legend(['actual','predication'])
plt.title("Actual val VS Pred val")
plt.show()

# %%
from sklearn.metrics import r2_score

test_pred=model.predict(x_test).flatten()
test_result=pd.DataFrame(data={"actual":y_test,"pred":test_pred})
r2=np.round(r2_score(y_test,test_pred),2)
print (r2)
print ("-------------------------------------")
test_result
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.98
# -------------------------------------
#       actual      pred
# 0        3.2  4.175438
# 1        2.4  2.754466
# 2        1.8  2.164994
# 3        1.7  1.516273
# 4        0.5  1.099649
# ...      ...       ...
# 1274     0.1 -1.198738
# 1275     0.2 -0.073229
# 1276    -0.5  0.150403
# 1277    -0.2 -0.244899
# 1278     0.0 -0.172614
#
# [1279 rows x 2 columns]

# %%
fig=plt.figure(figsize=(15,8))
plt.plot(y_test)
plt.plot(test_pred)
plt.legend(['actual','predication'])
plt.title("Actual train VS Pred train")
plt.show()
